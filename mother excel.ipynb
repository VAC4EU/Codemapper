# %%
import polars as pl
import json

# %%
projects0 = pl.read_csv('VAC4EU PASS CovidVaccineMonitoringVariables_2025_w23(CDM_EVENTS).csv')

name_colunm = 'Event_abbreviation / Variable Name'
descendants_column = 'Descendants_Rule'
project_columns = "GCOVS	RSV-adult	RSV-MATERNAL	Paxlovid_1037	Paxlovid_1047	ROC18	SAFETY-VAC (OBJ3)	Pfizer pregnancy algorithm	Pfizer	Pfizer_Myo	1052	AZ	Moderna	Moderna Pregnancy	Moderna_Myo	J&J	ROC20	ADEPT	CONSIGN	ALL	EMA_ROC11_CONSIGN	EMA_ROC12_effectiveness	Conception	ConcePTIONAlgorithmPregnancies".split('\t')

projects = (
    projects0
    .rename({})[[name_colunm, descendants_column] + project_columns]
    .filter(pl.col(name_colunm).is_not_null())
    .with_columns(pl.col(name_colunm).str.strip_chars())
)
projects
# Out:
# shape: (740, 26)
# ┌────────────┬────────────┬───────┬───────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ Event_abbr ┆ Descendant ┆ GCOVS ┆ RSV-adult ┆ … ┆ EMA_ROC11_ ┆ EMA_ROC12 ┆ Conceptio ┆ ConcePTIO │
# │ eviation / ┆ s_Rule     ┆ ---   ┆ ---       ┆   ┆ CONSIGN    ┆ _effectiv ┆ n         ┆ NAlgorith │
# │ Variable … ┆ ---        ┆ str   ┆ str       ┆   ┆ ---        ┆ eness     ┆ ---       ┆ mPregnanc │
# │ ---        ┆ bool       ┆       ┆           ┆   ┆ str        ┆ ---       ┆ str       ┆ ies       │
# │ str        ┆            ┆       ┆           ┆   ┆            ┆ str       ┆           ┆ ---       │
# │            ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆ str       │
# ╞════════════╪════════════╪═══════╪═══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ B_ANAEMIA_ ┆ true       ┆ yes   ┆ null      ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ COV        ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# │ B_ANAEMIAC ┆ false      ┆ null  ┆ null      ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ OLITIS_AES ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# │ I          ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# │ B_AIHEMOLY ┆ false      ┆ null  ┆ null      ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ TICANEMIA_ ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# │ AESI       ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# │ B_ARTERIAL ┆ false      ┆ null  ┆ null      ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ EMBOLISM_A ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# │ ESI        ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# │ B_COAGDEF_ ┆ false      ┆ null  ┆ null      ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ AESI       ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …     ┆ …         ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ O_SEVERMAL ┆ null       ┆ null  ┆ yes       ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ NUTRITION_ ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# │ AESI       ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# │ I_LISTERIA ┆ null       ┆ null  ┆ yes       ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ INFECT_COV ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# │ I_INFECPNE ┆ null       ┆ null  ┆ yes       ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ UMONIA_AES ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# │ I          ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# │ I_HSVDESSE ┆ null       ┆ null  ┆ yes       ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ MINATED_CO ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# │ V          ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# │ I_PNEUMOCY ┆ null       ┆ null  ┆ yes       ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ TOSJIROVEC ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# │ _COV       ┆            ┆       ┆           ┆   ┆            ┆           ┆           ┆           │
# └────────────┴────────────┴───────┴───────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
uri = "postgresql://localhost:5432/codemapper"
query = "SELECT id, name, meta FROM case_definitions WHERE project_id = 47 AND state is NULL"
mappings = pl.read_database_uri(query=query, uri=uri)
mappings = mappings.with_columns(
    pl.concat_str(
        pl.col('meta').str.json_path_match("$.system"),
        pl.col("name"),
        pl.col("meta").str.json_path_match("$.type"),
        separator='_'
    ).alias(name_colunm)).drop(["name", "meta"])
mappings
# Out:
# shape: (663, 2)
# ┌──────┬─────────────────────────────────┐
# │ id   ┆ Event_abbreviation / Variable … │
# │ ---  ┆ ---                             │
# │ i64  ┆ str                             │
# ╞══════╪═════════════════════════════════╡
# │ 2754 ┆ G_ALLKIDNEYDISEASE_COV          │
# │ 2809 ┆ I_NEOSEPSIS_AESI                │
# │ 3087 ┆ P_BirthPossible1_PrA            │
# │ 2915 ┆ M_MYOSITIS_COV                  │
# │ 3144 ┆ P_Gestationlessthan24weeksC_Pr… │
# │ …    ┆ …                               │
# │ 3228 ┆ P_StartofPregnancy_PrA          │
# │ 3340 ┆ SO_ANOSMIAAGEUSIA_AESI          │
# │ 3369 ┆ TP_DRAINWITHPERICARDIOSCOPY_CO… │
# │ 3398 ┆ TP_THORACOSCOPICVIDEO_COV       │
# │ 3427 ┆ V_VASCULITISSINGLEORG_AESI      │
# └──────┴─────────────────────────────────┘

# %%
projects_mappings = mappings.join(projects, on=name_colunm, how="right")
projects_mappings.to_pandas()
# Out:
#          id Event_abbreviation / Variable Name Descendants_Rule GCOVS  \
# 0    2461.0                      B_ANAEMIA_COV             True   yes
# 1    2462.0              B_ANAEMIACOLITIS_AESI            False  None
# 2    2460.0           B_AIHEMOLYTICANEMIA_AESI            False  None
# 3    2463.0            B_ARTERIALEMBOLISM_AESI            False  None
# 4    2464.0                     B_COAGDEF_AESI            False  None
# ..      ...                                ...              ...   ...
# 741  3440.0           O_SEVERMALNUTRITION_AESI             None  None
# 742  3441.0               I_LISTERIAINFECT_COV             None  None
# 743  3442.0              I_INFECPNEUMONIA_AESI             None  None
# 744  3443.0              I_HSVDESSEMINATED_COV             None  None
# 745     NaN           I_PNEUMOCYTOSJIROVEC_COV             None  None
#
#     RSV-adult RSV-MATERNAL Paxlovid_1037 Paxlovid_1047 ROC18  \
# 0        None         None          None          None   yes
# 1        None         None          None          None   yes
# 2        None         None          None          None   yes
# 3        None         None          None          None   yes
# 4        None         None          None          None   yes
# ..        ...          ...           ...           ...   ...
# 741       yes         None          None          None  None
# 742       yes         None          None          None  None
# 743       yes         None          None          None  None
# 744       yes         None          None          None  None
# 745       yes         None          None          None  None
#
#     SAFETY-VAC (OBJ3)  ... Moderna_Myo   J&J ROC20 ADEPT CONSIGN  ALL  \
# 0                None  ...         yes   yes  None  None    None  yes
# 1                None  ...        None  None  None  None    None  yes
# 2                None  ...        None  None  None  None    None  yes
# 3                None  ...         yes  None  None  None    None  yes
# 4                None  ...        None  None  None  None    None  yes
# ..                ...  ...         ...   ...   ...   ...     ...  ...
# 741              None  ...        None  None  None  None    None  yes
# 742              None  ...        None  None  None  None    None  yes
# 743              None  ...        None  None  None  None    None  yes
# 744              None  ...        None  None  None  None    None  yes
# 745              None  ...        None  None  None  None    None  yes
#
#     EMA_ROC11_CONSIGN EMA_ROC12_effectiveness Conception  \
# 0                None                    None       None
# 1                None                    None       None
# 2                None                    None       None
# 3                None                    None       None
# 4                None                    None       None
# ..                ...                     ...        ...
# 741              None                    None       None
# 742              None                    None       None
# 743              None                    None       None
# 744              None                    None       None
# 745              None                    None       None
#
#     ConcePTIONAlgorithmPregnancies
# 0                             None
# 1                             None
# 2                             None
# 3                             None
# 4                             None
# ..                             ...
# 741                           None
# 742                           None
# 743                           None
# 744                           None
# 745                           None
#
# [746 rows x 27 columns]

# %%
missing = projects_mappings.filter(pl.col("id").is_null())[name_colunm]
print(len(missing))
missing.str.join(', ')[0]
# Out:
# 89
# 'B_COAGDEF_COV, B_COAGDIS_AESI, B_SICKLECELLALGORITHM_COV, B_TTS_AESI, C_ACI_AESI, C_CARDIOCEREBROVASCULARDESE_COV, C_CARDIOMYOPATHYALL_COV, C_CVD_COV, C_FULMINANTMYOCARDALGOR_AESI, C_INFLAMCARDIOMYOPATHY_COV, C_MYOPERICARD_AESI, D_LIVERCHRONIC_COV, D_DIGESTIVEDIS_AESI, E_DM12ALGORITHM_COV, E_DM12ALGORITHM_COV, H_PRIMARYHCUSE_COV, H_LCF_COV, I_COVID_COV, I_COVIDTESTPOS_COV, I_HIV_COV, I_RESPINFECALGORITHM_COV, Im_ALLERGY_COV, Im_ALLERGIES_COV, Im_ANAPHYLAXIS_COV, Im_AUTOIMM_COV, IM_IMC_COV, Im_IMMUNOSUPPRESSION_COV, Im_IMMUNOLOGICALSYNDROM_COV, Im_IMMCOMPMATCHPFIZER_COV, Im_IMMUNODEFIMMUNOSUP_COV, Im_ IRIS_AESI, Im_ STILLDISEASE_AESI, L_Activity limitation_COV, L_CHARLSON_COV, L_BMIPREGN_COV, L_EDUCATION_COV, L_GEOREGION_COV, L_Housebound_COV, L_ImpairedMobility_COV, L_MARITALSTAT_COV, L_PREGNSTATUS_COV, L_OBESITYALGORITHM_COV, L_RACE_COV, L_SEX_COV, L_SMOKEPREGN_COV, L_SOCIOECO_COV, L_WCHILDBEARING_COV, M_CONNTISDIS_COV, Ment_ADHD_AESI, Ment_Autism_AESI, Ment_MENTHEALTHDISEASEALGOR_COV, Ment_LANGUAGEDIS_AESI, N_CEREBROVASC_AESI, N_CEREBHEMO_COV, N_CONVULSIONALGOR_AESI, N_DEMYELALL_AESI, N_ENCEPHALITISALL_AESI, N_Epilepsy_AESI, N_NEURODISCHRONIC_COV, N_STROKEALGOR_AESI, O_DEATHANY_AESI, O_MORBSUNSTAB_COV, O_PAINALGOR_COV, Onc_ANYMALIGNALGOPFIZER_COV, Onc_ANYMALIGNANCYALGORITHM_COV, Onc_BreastCancer_AESI, Onc_CANCER_COV, Onc_METASTATICSOLIDTUMOR_COV, Onc_METASTASIS_COV, P_MATERNALTORCH_COV, P_INFERTILITYTREAT_COV, P_CACS_AESI, P_Gestationlessthan24weeksCHILD_PrA, P_MAJORCA_AESI, P_NEONATALDEATH_AESI, P_PregnancyAlgorithm_PrA, P_TOPFA_AESI, P_HYPERTENSIONALL_COV, P_PRAYPERTESION_AESI, P_PRAYPERTESION_AESI, R_CHRONICPULMONARYDISEASE_COV, R_ASTHMAEXACERBATIONALGOR_AESI, R_RESPCHRONICALGORITHM_COV, R_RESPCHRONIC_COV, TP_CARDIOCATETPERICARDCENT_COV, TP_INFERTILITY_COV, V_THROMBOSISARTERIALALGOR_AESI, V_VTEALGORITHM_AESI, I_PNEUMOCYTOSJIROVEC_COV'

# %%
final.filter(pl.col(name_colunm).str.contains("P_24weeksCHILD_PrA"))
# Out:
# shape: (1, 4)
# ┌──────┬─────────────────────────────────┬─────────────────────────────────┬──────────────────┐
# │ id   ┆ Event_abbreviation / Variable … ┆ Projects                        ┆ Descendants_Rule │
# │ ---  ┆ ---                             ┆ ---                             ┆ ---              │
# │ i64  ┆ str                             ┆ str                             ┆ bool             │
# ╞══════╪═════════════════════════════════╪═════════════════════════════════╪══════════════════╡
# │ 3075 ┆ P_24weeksCHILD_PrA              ┆ ["ROC18", "Pfizer pregnancy al… ┆ false            │
# └──────┴─────────────────────────────────┴─────────────────────────────────┴──────────────────┘

# %%
final = (
    projects_mappings
        .unpivot(index=['id', name_colunm, descendants_column], on=project_columns, variable_name='Project')
        .filter(pl.col("value").is_not_null())
        .group_by(['id', name_colunm])
        .agg([
            pl.col("Project").alias("Projects"),
            pl.col(descendants_column).any()
        ])
        .with_columns(pl.col("Projects").map_elements(lambda e: json.dumps(list(e))))
        .filter(pl.col("id").is_not_null())
)
final.to_pandas()
# Out:
# /var/folders/nq/3btdw2q57jg3psxwfgpjccs80000gn/T/ipykernel_15182/1106942334.py:10: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   .with_columns(pl.col("Projects").map_elements(lambda e: json.dumps(list(e))))
#        id Event_abbreviation / Variable Name  \
# 0    3156              P_LABORINDUCTION_AESI
# 1    2848    Im_HYPERSENSITIVITYSMALLPOX_COV
# 2    2734      E_DIABETESNOCOMPLICATIONS_COV
# 3    2988                     O_ANOREXIA_COV
# 4    3173                   P_MINCALIMB_AESI
# ..    ...                                ...
# 633  2852                   Im_KAWASAKI_AESI
# 634  2725       D_MODERATESEVERHEPAIMPAI_COV
# 635  3408                          V_DVT_COV
# 636  2787                         I_CMV_AESI
# 637  3423                     V_TAKAYASU_COV
#
#                                               Projects  Descendants_Rule
# 0                             ["Paxlovid_1037", "ALL"]             False
# 1                                ["Pfizer_Myo", "ALL"]              True
# 2    ["ROC18", "Pfizer", "Pfizer_Myo", "1052", "AZ"...              True
# 3                        ["Moderna_Myo", "J&J", "ALL"]              True
# 4                                     ["ADEPT", "ALL"]             False
# ..                                                 ...               ...
# 633  ["ROC18", "Pfizer_Myo", "Moderna", "J&J", "ROC...             False
# 634                           ["Paxlovid_1047", "ALL"]              True
# 635           ["ROC18", "Pfizer", "Pfizer_Myo", "ALL"]              True
# 636              ["ROC18", "SAFETY-VAC (OBJ3)", "ALL"]             False
# 637                              ["Pfizer_Myo", "ALL"]              True
#
# [638 rows x 4 columns]

# %%
print(final.columns)
final.write_csv('mother excel.csv', include_header=False)
# Out:
# ['id', 'Event_abbreviation / Variable Name', 'Projects', 'Descendants_Rule']

# %% [markdown]
# ```sql
# create temp table mother (case_definition_id int, name text, projects text, descendants boolean);
# copy mother from '/home/bb/mother excel.csv' (FORMAT csv);
#
# update case_definitions cd
# set meta = jsonb_set(meta, '{projects}', projects::JSONB)
# from mother
# where cd.id = mother.case_definition_id;
#
# update case_definition_revisions r
# set mapping = jsonb_set(mapping, '{meta, includeDescendants}', to_jsonb(mother.descendants), true)
# from mother
# join (
#     select case_definition_id, max(version) as version
#     from case_definition_revisions
#     group by case_definition_id
# ) as latest
# on mother.case_definition_id = latest.case_definition_id
# where r.case_definition_id = latest.case_definition_id
# and r.version = latest.version;
#
#
#
#
# ```
